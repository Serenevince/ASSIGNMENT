# %% [markdown]
# Q1. Load the Iris dataset using Pandas and display the first 5 rows.

# %%
import pandas as pd

# %%
df_iris=pd.read_excel('/content/sample_data/iris.xls')

# %%
df_iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df_iris.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %% [markdown]
# Q2. Calculate and display the mean, median, and standard deviation of sepal length (cm) for the entire dataset.

# %%
df_iris['SL'].mean()
# Out:
# 5.843333333333334

# %%
df_iris['SL'].median()
# Out:
# 5.8

# %%
df_iris['SL'].std()
# Out:
# 0.828066127977863

# %% [markdown]
# Q3. Find the maximum value of petal width (cm) and the corresponding species (target class).

# %%
df_iris[['PW','Classification']].max()
# Out:
# PW                           2.5
# Classification    Iris-virginica
# dtype: object

# %% [markdown]
# Q4. Filter the dataset to show only the rows where petal length (cm) is between 4.5 and 5.0.

# %%
df_iris.iloc[:,[2]]
# Out:
#       PL
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# ..   ...
# 145  5.2
# 146  5.0
# 147  5.2
# 148  5.4
# 149  5.1
#
# [150 rows x 1 columns]

# %%
df_iris.loc[df_iris["PL"]==4.5]
# Out:
#       SL   SW   PL   PW   Classification
# 51   6.4  3.2  4.5  1.5  Iris-versicolor
# 55   5.7  2.8  4.5  1.3  Iris-versicolor
# 66   5.6  3.0  4.5  1.5  Iris-versicolor
# 68   6.2  2.2  4.5  1.5  Iris-versicolor
# 78   6.0  2.9  4.5  1.5  Iris-versicolor
# 84   5.4  3.0  4.5  1.5  Iris-versicolor
# 85   6.0  3.4  4.5  1.6  Iris-versicolor
# 106  4.9  2.5  4.5  1.7   Iris-virginica

# %%
df_iris.loc[df_iris["PL"]==4.6]
# Out:
#      SL   SW   PL   PW   Classification
# 54  6.5  2.8  4.6  1.5  Iris-versicolor
# 58  6.6  2.9  4.6  1.3  Iris-versicolor
# 91  6.1  3.0  4.6  1.4  Iris-versicolor

# %%
df_iris.loc[df_iris["PL"]==4.7]
# Out:
#      SL   SW   PL   PW   Classification
# 50  7.0  3.2  4.7  1.4  Iris-versicolor
# 56  6.3  3.3  4.7  1.6  Iris-versicolor
# 63  6.1  2.9  4.7  1.4  Iris-versicolor
# 73  6.1  2.8  4.7  1.2  Iris-versicolor
# 86  6.7  3.1  4.7  1.5  Iris-versicolor

# %%
df_iris.loc[df_iris["PL"]==4.8]
# Out:
#       SL   SW   PL   PW   Classification
# 70   5.9  3.2  4.8  1.8  Iris-versicolor
# 76   6.8  2.8  4.8  1.4  Iris-versicolor
# 126  6.2  2.8  4.8  1.8   Iris-virginica
# 138  6.0  3.0  4.8  1.8   Iris-virginica

# %%
df_iris.loc[df_iris["PL"]==4.9]
# Out:
#       SL   SW   PL   PW   Classification
# 52   6.9  3.1  4.9  1.5  Iris-versicolor
# 72   6.3  2.5  4.9  1.5  Iris-versicolor
# 121  5.6  2.8  4.9  2.0   Iris-virginica
# 123  6.3  2.7  4.9  1.8   Iris-virginica
# 127  6.1  3.0  4.9  1.8   Iris-virginica

# %% [markdown]
# Q5. Use iloc to display the values of the first row in the dataset.

# %%
df_iris.iloc[0]
# Out:
# SL                        5.1
# SW                        3.5
# PL                        1.4
# PW                        0.2
# Classification    Iris-setosa
# Name: 0, dtype: object

# %% [markdown]
# Q6. Use loc to display all columns for the sample with index 10.

# %%
df_iris.loc[10]
# Out:
# SL                        5.4
# SW                        3.7
# PL                        1.5
# PW                        0.2
# Classification    Iris-setosa
# Name: 10, dtype: object

# %% [markdown]
# Q7. Use iloc to display the values of the last row in the dataset.

# %%
df_iris.iloc[-1]
# Out:
# SL                           5.9
# SW                           3.0
# PL                           5.1
# PW                           1.8
# Classification    Iris-virginica
# Name: 149, dtype: object

# %% [markdown]
# Q8. Use loc to display the petal length and petal width for samples with indices 25 to 30 (inclusive).

# %%
df_iris.loc[25:30,["PL"]]
# Out:
#      PL
# 25  1.6
# 26  1.6
# 27  1.5
# 28  1.4
# 29  1.6
# 30  1.6

# %%
df_iris.loc[25:30,["PW"]]
# Out:
#      PW
# 25  0.2
# 26  0.4
# 27  0.2
# 28  0.2
# 29  0.2
# 30  0.2

# %% [markdown]
# Q9. . Use iloc to display the sepal length and sepal width for the first 10 samples.

# %%
df_iris.iloc[:10,[0,1]]
# Out:
#     SL   SW
# 0  5.1  3.5
# 1  4.9  3.0
# 2  4.7  3.2
# 3  4.6  3.1
# 4  5.0  3.6
# 5  5.4  3.9
# 6  4.6  3.4
# 7  5.0  3.4
# 8  4.4  2.9
# 9  4.9  3.1

# %% [markdown]
# Q10. Use loc to display all columns for samples with target class 1.

# %%
df_iris.loc[df_iris['Classification']=="Iris-virginica"]
# Out:
#       SL   SW   PL   PW  Classification
# 100  6.3  3.3  6.0  2.5  Iris-virginica
# 101  5.8  2.7  5.1  1.9  Iris-virginica
# 102  7.1  3.0  5.9  2.1  Iris-virginica
# 103  6.3  2.9  5.6  1.8  Iris-virginica
# 104  6.5  3.0  5.8  2.2  Iris-virginica
# 105  7.6  3.0  6.6  2.1  Iris-virginica
# 106  4.9  2.5  4.5  1.7  Iris-virginica
# 107  7.3  2.9  6.3  1.8  Iris-virginica
# 108  6.7  2.5  5.8  1.8  Iris-virginica
# 109  7.2  3.6  6.1  2.5  Iris-virginica
# 110  6.5  3.2  5.1  2.0  Iris-virginica
# 111  6.4  2.7  5.3  1.9  Iris-virginica
# 112  6.8  3.0  5.5  2.1  Iris-virginica
# 113  5.7  2.5  5.0  2.0  Iris-virginica
# 114  5.8  2.8  5.1  2.4  Iris-virginica
# 115  6.4  3.2  5.3  2.3  Iris-virginica
# 116  6.5  3.0  5.5  1.8  Iris-virginica
# 117  7.7  3.8  6.7  2.2  Iris-virginica
# 118  7.7  2.6  6.9  2.3  Iris-virginica
# 119  6.0  2.2  5.0  1.5  Iris-virginica
# 120  6.9  3.2  5.7  2.3  Iris-virginica
# 121  5.6  2.8  4.9  2.0  Iris-virginica
# ...
